# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import torch
import pandas
import numpy as np
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#import pandas
#dataset taken from https://www.kaggle.com/yashsawarn/wifi-stretgth-for-rooms

def read_dataset(csv_name = 'sao-paulo-properties-april-2019.csv'):
    """
    Reads a csv dataset 
    returns it as a pytorch tensor
    """
    data_frame = pandas.read_csv(csv_name)

    """
    Creates a new column with categories using the "price" column
      1) 900000 < y , categoría 4
      2) 580000 < y < 900000, categoría 3
      3) 400000 < y < 580000, categoría 2
      4) y < 400000, categoría 1    
    """
    data_frame.loc[ data_frame['Price'] <  400000, 'Class'] = 1
    data_frame.loc[(data_frame['Price'] >= 400000) & (data_frame['Price'] < 580000), 'Class'] = 2
    data_frame.loc[(data_frame['Price'] >= 580000) & (data_frame['Price'] < 900000), 'Class'] = 3
    data_frame.loc[ data_frame['Price'] >= 900000, 'Class'] = 4
    data_frame['Class'] = data_frame['Class'].astype('int')
    
    return data_frame

# %%
class Node_CART:    
    def __init__(self, num_classes = 4, ref_CART = None, current_depth = 0):
        """
        Create the node attributes
        param num_classes: K number of classes to classify
        param ref_cart: reference to the tree containing the node
        param current_depth: current depth of the node in the tree
        """
        self.ref_CART = ref_CART
        self.threshold_value = 0
        self.feature_num = 0
        self.node_right = None
        self.node_left = None
        self.data_torch_partition = None
        self.gini = 0
        self.dominant_class = None #Atributo con Mayor Cantidad de apariciones en el dataset
        self.accuracy_dominant_class = None        
        self.num_classes = num_classes
        self.current_depth = current_depth
    
    def to_xml(self, current_str = ""):
        """
        Recursive function to write the node content to an xml formatted string
        param current_str : the xml content so far in the whole tree
        return the string with the node content
        """
        str_node = "<node><thresh>" + str(self.threshold_value) + "</thresh>" + "<feature>" + str(self.feature_num) + "</feature><depth>" + str(self.current_depth)+ "</depth>" 
        str_node += "<gini>" + str(self.gini) + "</gini>"
        if(self.node_right != None):
            str_left = self.node_right.to_xml(current_str)
            str_node += str_left
        if(self.node_left != None):
            str_right = self.node_left.to_xml(current_str)
            str_node += str_right
            
        if(self.is_leaf()):
            str_node += "<dominant_class>" + str(self.dominant_class) + "</dominant_class><acc_dominant_class>"  + str(self.accuracy_dominant_class) + "</acc_dominant_class>"
        str_node += "</node>"
        return str_node
    
    def is_leaf(self):
        """
        Checks whether the node is a leaf
        """
        return (self.node_left == None and self.node_right == None)
    
    def create_with_children(self, data_torch, current_depth, list_selected_features = [], min_gini = 0.000001):
        """
        Creates a node by selecting the best feature and threshold, and if needed, creating its children
        param data_torch: dataset with the current partition to deal with in the node
        param current_depth: depth counter for the node
        param list_selected_features: list of selected features so far for the CART building process
        param min_gini: hyperparmeter selected by the user defining the minimum tolerated gini coefficient for a  node
        return the list of selected features so far
        """        
        #update depth of children
        depth_children = current_depth + 1
        if(depth_children <= self.ref_CART.get_max_depth()):
            num_observations = data_torch.shape[0]            
            #careful with max depth
            #if no threshold and feature were selected, select it using a greedy approach            
            (threshold_value, feature_num, gini) = self.select_best_feature_and_thresh(data_torch, list_features_selected = list_selected_features)
            list_selected_features += [feature_num]
            #store important data in attributes
            self.threshold_value = threshold_value
            self.feature_num = feature_num
            self.data_torch_partition = data_torch
            self.gini = gini            
            num_features = data_torch.shape[1]
            #data_torch_left = torch.zeros(1, num_features)
            #data_torch_right = torch.zeros(1, num_features)
            #create the right and left node data if the current gini is still high            
            if(self.gini > min_gini):                
                data_torch_left = data_torch[data_torch[:, feature_num] < threshold_value]
                data_torch_right = data_torch[data_torch[:, feature_num] >= threshold_value]
                #if the new partitions have more than min_observations, make them
                if(data_torch_left.shape[0] >= self.ref_CART.get_min_observations() and data_torch_right.shape[0] >= self.ref_CART.get_min_observations()):
                    #add data to the right and left children
                    self.node_right = Node_CART(num_classes = self.num_classes, ref_CART = self.ref_CART, current_depth = depth_children)
                    self.node_left = Node_CART(num_classes = self.num_classes, ref_CART = self.ref_CART, current_depth = depth_children)
                    list_selected_features = self.node_right.create_with_children(data_torch_right, depth_children, list_selected_features = list_selected_features)            
                    self.node_left.create_with_children( data_torch_left, depth_children, list_selected_features = list_selected_features)
        #if is leaf, fill the         
        if(self.is_leaf()):            
            labels_data = data_torch[:,  -1]
            self.dominant_class = torch.mode(labels_data).values.item()
            num_obs_label = labels_data[labels_data == self.dominant_class].shape[0]
            self.accuracy_dominant_class = num_obs_label / labels_data.shape[0]           
            
        return list_selected_features
    
 #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@   
    def select_best_feature_and_thresh(self, data_torch, list_features_selected = [], num_classes = 4):
        """
        ONLY USE  2 FORS
        Selects the best feature and threshold that minimizes the gini coefficient
        param data_torch: dataset partition to analyze
        param list_features_selected list of features selected so far, thus must be ignored 
        param num_classes: number of K classes to discriminate from 
        return min_thresh, min_feature, min_gini found for the dataset partition when 
        selecting the found feature and threshold
        """       

        
        #TODO
        #Defining null vector for Ginis
        giniVec=pandas.DataFrame(columns=[data_torch.columns])

        #display(giniVec)
        #print("nodo_test: Min Threshold = %s, Feature=%s, Min Gini=%s"%(nodo_test.select_best_feature_and_thresh(dataset_cut)))

        for col in data_torch.columns:
            nClasses = data_torch.groupby([data_torch[[col]].columns.item()]).size().array
            giniVec[col] = [self.calculate_gini(data_torch[[col]], num_classes=nClasses)]
            print("\n Valores unicos de %s, %s:"%(col, data_torch[col].sort_values().unique()))
            print('Cantidad por valores \n', data_torch.groupby([col]).size())
            
            #Defining null vector for Thresholds per column
            threshVec=pandas.DataFrame(columns=data_torch[col].sort_values().unique())
            #print("Vector nulo para threshold de la columna: ", col)
            #print("Vector threshold : ", threshVec)
            
            #Calculates the threshold
            for val in data_torch[col].sort_values().unique() :
                filter_ = data_torch[col]<val
                
                valGiniI = self.calculate_gini(data_torch[col])
                #valGiniD =
                #threshVec[val]=
                

            #threshVec[col] = [len(nClasses)] Esto es un error
            
        #display(giniVec)
        """
        print('Min Gini value : ', giniVec[min(giniVec)].item())
        print('Min feature value : ', min(giniVec)[0])
        print('Min Threshold value : ', threshVec[min(giniVec)].item())
        display(threshVec)
        """
        return (len(nClasses), min(giniVec)[0], giniVec[min(giniVec)].item())   
        
    
    def calculate_gini(self, data_partition_torch, num_classes = 4):
        """
        Calculates the gini coefficient for a given partition with the given number of classes
        param data_partition_torch: current dataset partition as a tensor
        param num_classes: K number of classes to discriminate from
        returns the calculated gini coefficient
        """
        #TODO
        gini = 1 - sum((num_classes / data_partition_torch.shape[0]) **2)
        #print("calculate_gini => num_classes: ", num_classes, data_partition_torch.shape[0])
        #print("Result Gini: ", gini)

        return gini
    
   
    
    def evaluate_node(self, input_torch): 
        """
        Evaluates an input observation within the node. 
        If is not a leaf node, send it to the corresponding node
        return predicted label
        """
        feature_val_input = input_torch[self.feature_num]
        if(self.is_leaf()):
            return self.dominant_class
        else:
            if(feature_val_input < self.threshold_value):
                return self.node_left.evaluate_node(input_torch)
            else:
                return self.node_right.evaluate_node(input_torch)
        

#*******************************************************************************************************************

class CART:
   
    def __init__(self, dataset_torch, max_CART_depth = 4, min_observations = 2):
        """
        CART has only one root node
        """
        #min observations per node
        self.min_observations = min_observations
        self.root = Node_CART(num_classes = 4, ref_CART = self, current_depth = 0)
        self.max_CART_depth = max_CART_depth
        self.list_selected_features = []
        
    def get_root(self):
        """
        Gets tree root
        """
        return self.root
    
    def get_min_observations(self):
        """
        return min observations per node
        """
        return self.min_observations
    
    def get_max_depth(self):
        """
        Gets the selected max depth of the tree
        """
        return self.max_CART_depth
    
    def build_CART(self, data_torch):
        """
        Build CART from root
        """
        self.list_selected_features = self.root.create_with_children(data_torch, current_depth = 0)
    
    def to_xml(self, xml_file_name):
        """
        write Xml file with tree content
        """
        str_nodes = self.root.to_xml()
        print('str_nodes ', str_nodes)
        file = open(xml_file_name,"w+") 
        file.write(str_nodes)
        file.close()
        return str_nodes
    
    
    def evaluate_input(self, input_torch):
        """
        Evaluate a specific input in the tree and get the predicted class
        """
        return self.root.evaluate_node(input_torch)
        
    
def train_CART(dataset_torch, name_xml = "", max_CART_depth = 3, min_obs_per_leaf = 2): 
    """
    Train CART model
    """
    tree = CART(dataset_torch = dataset_torch, max_CART_depth = max_CART_depth, min_observations =  min_obs_per_leaf)
    tree.build_CART(dataset_torch)
    if(not name_xml == ""):
        tree.to_xml(name_xml)
    return tree

def test_CART(tree, testset_torch):
    """
    Test a previously built CART
    """
    #TODO, use tree.evaluate_input(current_observation) for this
    return accuracy

# %%
"""
Main function
"""
def main():

    dataset_torch = read_dataset()
    """
    display(dataset_torch)
    print(dataset_torch.describe())
    print("size full dataset: ",dataset_torch.size)
    """
    
    dataset_cut=dataset_torch[['Rooms','Size','Toilets','Parking']].copy()
    

    """
    display(dataset_cut)
    print(dataset_cut.describe())
    """
    #print('dataset_cut size: ',dataset_cut.size)
    
    giniBest = pandas.DataFrame(columns=['col', 'thresh','giniW'])
    display(giniBest)
    i=0
    for col in dataset_cut.columns :
        giniWVal=pandas.DataFrame([])
        for val in dataset_cut[col].sort_values().unique() :
            totCol = dataset_cut[col].shape[0]
            filter_ = dataset_cut[col]<val
            Xi = pandas.DataFrame(dataset_cut[col][filter_].copy())
            Xd = pandas.DataFrame(dataset_cut[col][~filter_].copy())
            #print('\n Col=%s, Val=%s, Xi :\n %s'%(col, val, Xi))
            #print('\n Col=%s, Val=%s, Xd :\n %s'%(col, val, Xd))
        
            #Calculates for each value in the column the left and right gini and the weighted gini per value
            if Xi.empty :
                giniI = 0.0
                            #self.calculate_gini(data_torch[col]) #Modificar para usar esta funcion
                qtyClassD = Xd.groupby([Xd[[col]].columns.item()]).size().array
                totQtyD   = Xd.shape[0]
                giniD = 1 - sum((qtyClassD/totQtyD)**2)
                giniW = giniD
            elif Xd.empty :
                giniD = 0.0
                qtyClassI = Xi.groupby([Xi[[col]].columns.item()]).size().array
                totQtyI   = Xi.shape[0]
                giniI = 1 - sum((qtyClassI/totQtyI)**2)
                giniW = giniI
            else :
                qtyClassI = Xi.groupby([Xi[[col]].columns.item()]).size().array
                totQtyI   = Xi.shape[0]
                giniI = 1 - sum((qtyClassI/totQtyI)**2)
                qtyClassD = Xd.groupby([Xd[[col]].columns.item()]).size().array
                totQtyD   = Xd.shape[0]
                giniD = 1 - sum((qtyClassD/totQtyD)**2)
                giniW = ((totQtyI/totCol)*giniI)+((totQtyD/totCol)*giniD)
            #Gets the minimun value for weighted gini
            if giniWVal.empty :
                giniWVal['Thresh']= [val]
                giniWVal['GiniW'] = [giniW]
            else :
                if giniW < giniWVal['GiniW'].item() :
                    giniWVal['Thresh']= [val]
                    giniWVal['GiniW'] = [giniW]
            
                
            print('\n Col=%s, Val=%s, XiShape=%s, XdShape=%s, giniI=%s, giniD=%s, ginigW=%s'%(col, val, Xi.shape[0], Xd.shape[0], giniI, giniD, giniW))
            print('Valores en giniWVal: \n', giniWVal)
        inter = pandas.DataFrame([[col, giniWVal['Thresh'].item(), giniWVal['GiniW'].item()]], columns=['col', 'thresh','giniW'])    
        giniBest=pandas.concat([giniBest, inter], ignore_index=True)
        display(giniBest)
        
        print('Index : ', giniBest.index[giniBest['giniW'] == min(giniBest.giniW)].item())
        
    #tree = train_CART(dataset_torch, name_xml = "CART_example.xml")
    #acc = test_CART(tree, dataset_torch)
    
    """
    CART_1 =  CART(dataset_torch)
    CART_1.to_xml("arbolito_vacio.xml")
    nodo_A = Node_CART(num_classes = 2, current_depth = 1)
    CART_1.root.node_left = nodo_A
    CART_1.to_xml("arbolito_peque.xml")

    #print(CART_1.ref_CART)
    print(CART_1.threshold_value)
    print(CART_1.feature_num)
    print(CART_1.node_right)
    print(CART_1.node_left)
    print(CART_1.data_torch_partition)
    print(CART_1.gini)
    print(CART_1.dominant_class)
    print(CART_1.accuracy_dominant_class)
    print(CART_1.num_classes)
    print(CART_1.current_depth)
    #nClasses = data_torch.groupby([data_torch[[col]].columns.item()]).size().array
    X = dataset_torch.groupby([dataset_torch[['Rooms']].columns.item()]).size().array
    Q = dataset_torch.shape[0]
    print('Valores unicos de Rooms:', dataset_torch['Rooms'].sort_values().unique())
    print('Cantidad por valores de Rooms', dataset_torch.groupby(['Rooms']).size())
    print('Valores unicos de Toilets:', dataset_torch['Toilets'].sort_values().unique())
    print('Cantidad por Valores de Toilets', dataset_torch.groupby(['Toilets']).size())
    print('Valores unicos de Size:', dataset_torch['Size'].sort_values().unique())
    print('Cantidad por Valores de Size', dataset_torch.groupby(['Size']).size())
    print('Valores unicos de Parking:', dataset_torch['Parking'].sort_values().unique())
    print('Cantidad de Valores de Parking', dataset_torch.groupby(['Parking']).size())
    print("Vector X \n ", X, "\n Total suma \n", X.sum(), "\n Cantidad Rows \n", dataset_torch.shape[0])
    print("Gini \n", 1- sum((X/Q)**2))
    gini = 1 - sum((X/Q)**2)
    """
    
main()
# Out:
# Empty DataFrame
# Columns: [col, thresh, giniW]
# Index: []
#  Col=Rooms, Val=1, XiShape=0, XdShape=4894, giniI=0.0, giniD=0.6298064951637569, ginigW=0.6298064951637569
# Valores en giniWVal:
#     Thresh     GiniW
# 0       1  0.629806
#
#  Col=Rooms, Val=2, XiShape=436, XdShape=4458, giniI=0.0, giniD=0.5634195917793932, ginigW=0.5132252840524182
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.513225
#
#  Col=Rooms, Val=3, XiShape=2635, XdShape=2259, giniI=0.2761725278958984, giniD=0.24733802971185437, ginigW=0.26286293831728064
# Valores en giniWVal:
#     Thresh     GiniW
# 0       3  0.262863
#
#  Col=Rooms, Val=4, XiShape=4569, XdShape=325, giniI=0.5800846254179668, giniD=0.04815147928994079, ginigW=0.5447600907854354
# Valores en giniWVal:
#     Thresh     GiniW
# 0       3  0.262863
#
#  Col=Rooms, Val=5, XiShape=4886, XdShape=8, giniI=0.6285953384317577, giniD=0.21875, ginigW=0.6279253828315424
# Valores en giniWVal:
#     Thresh     GiniW
# 0       3  0.262863
#
#  Col=Rooms, Val=6, XiShape=4893, XdShape=1, giniI=0.6296552059150639, giniD=0.0, ginigW=0.6295265473114849
# Valores en giniWVal:
#     Thresh     GiniW
# 0       3  0.262863
#      col thresh     giniW
# 0  Rooms      3  0.262863
# Index :  0
#
#  Col=Size, Val=30, XiShape=0, XdShape=4894, giniI=0.0, giniD=0.9868289887002074, ginigW=0.9868289887002074
# Valores en giniWVal:
#     Thresh     GiniW
# 0      30  0.986829
#
#  Col=Size, Val=31, XiShape=12, XdShape=4882, giniI=0.0, giniD=0.986770202002826, ginigW=0.9843506592108289
# Valores en giniWVal:
#     Thresh     GiniW
# 0      31  0.984351
#
#  Col=Size, Val=32, XiShape=22, XdShape=4872, giniI=0.49586776859504145, giniD=0.9867200496924889, ginigW=0.9845135212527374
# Valores en giniWVal:
#     Thresh     GiniW
# 0      31  0.984351
#
#  Col=Size, Val=33, XiShape=26, XdShape=4868, giniI=0.6153846153846153, giniD=0.9866988918289178, ginigW=0.9847262373157278
# Valores en giniWVal:
#     Thresh     GiniW
# 0      31  0.984351
#
#  Col=Size, Val=34, XiShape=34, XdShape=4860, giniI=0.7197231833910034, giniD=0.9866577757455672, ginigW=0.9848033057537293
# Valores en giniWVal:
#     Thresh     GiniW
# 0      31  0.984351
#
#  Col=Size, Val=35, XiShape=49, XdShape=4845, giniI=0.7713452728029988, giniD=0.9865846185304821, ginigW=0.9844295862581799
# Valores en giniWVal:
#     Thresh     GiniW
# 0      31  0.984351
#
#  Col=Size, Val=36, XiShape=72, XdShape=4822, giniI=0.7920524691358024, giniD=0.9864790868480752, ginigW=0.9836187034244372
# Valores en giniWVal:
#     Thresh     GiniW
# 0      36  0.983619
#
#  Col=Size, Val=37, XiShape=91, XdShape=4803, giniI=0.8262287163386064, giniD=0.9863875503932604, ginigW=0.9834095254854195
# Valores en giniWVal:
#     Thresh    GiniW
# 0      37  0.98341
#
#  Col=Size, Val=38, XiShape=103, XdShape=4791, giniI=0.8507870675841267, giniD=0.9863255483946126, ginigW=0.983472981266807
# Valores en giniWVal:
#     Thresh    GiniW
# 0      37  0.98341
#
#  Col=Size, Val=39, XiShape=124, XdShape=4770, giniI=0.868366285119667, giniD=0.9862242615227069, ginigW=0.9832380765872806
# Valores en giniWVal:
#     Thresh     GiniW
# 0      39  0.983238
#
#  Col=Size, Val=40, XiShape=145, XdShape=4749, giniI=0.8827586206896552, giniD=0.9861217139129289, ginigW=0.9830592601905392
# Valores en giniWVal:
#     Thresh     GiniW
# 0      40  0.983059
#
#  Col=Size, Val=41, XiShape=175, XdShape=4719, giniI=0.8901224489795918, giniD=0.9859851117436508, ginigW=0.9825572478319813
# Valores en giniWVal:
#     Thresh     GiniW
# 0      41  0.982557
#
#  Col=Size, Val=42, XiShape=190, XdShape=4704, giniI=0.9005540166204986, giniD=0.9859057568605675, ginigW=0.9825921420984888
# Valores en giniWVal:
#     Thresh     GiniW
# 0      41  0.982557
#
#  Col=Size, Val=43, XiShape=215, XdShape=4679, giniI=0.90881557598702, giniD=0.9857832906812717, ginigW=0.9824019954913934
# Valores en giniWVal:
#     Thresh     GiniW
# 0      43  0.982402
#
#  Col=Size, Val=44, XiShape=228, XdShape=4666, giniI=0.9156663588796553, giniD=0.9857117240494893, ginigW=0.9824484745074538
# Valores en giniWVal:
#     Thresh     GiniW
# 0      43  0.982402
#
#  Col=Size, Val=45, XiShape=248, XdShape=4646, giniI=0.9222164412070759, giniD=0.9856069746674082, ginigW=0.9823947040711347
# Valores en giniWVal:
#     Thresh     GiniW
# 0      45  0.982395
#
#  Col=Size, Val=46, XiShape=331, XdShape=4563, giniI=0.8934566132109053, giniD=0.9854094686947568, ginigW=0.9791903442229228
# Valores en giniWVal:
#     Thresh    GiniW
# 0      46  0.97919
#
#  Col=Size, Val=47, XiShape=360, XdShape=4534, giniI=0.9034413580246914, giniD=0.9852631365934081, ginigW=0.9792443706995099
# Valores en giniWVal:
#     Thresh    GiniW
# 0      46  0.97919
#
#  Col=Size, Val=48, XiShape=422, XdShape=4472, giniI=0.9081444711484468, giniD=0.9850438906685527, ginigW=0.978413004882389
# Valores en giniWVal:
#     Thresh     GiniW
# 0      48  0.978413
#
#  Col=Size, Val=49, XiShape=522, XdShape=4372, giniI=0.9032677148016031, giniD=0.984875055350986, ginigW=0.9761707170251221
# Valores en giniWVal:
#     Thresh     GiniW
# 0      49  0.976171
#
#  Col=Size, Val=50, XiShape=595, XdShape=4299, giniI=0.910495021538027, giniD=0.9846453740168292, ginigW=0.9756303638564516
# Valores en giniWVal:
#     Thresh    GiniW
# 0      50  0.97563
#
#  Col=Size, Val=51, XiShape=776, XdShape=4118, giniI=0.8929748113508343, giniD=0.9851978343575546, ginigW=0.9705748131370366
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=52, XiShape=846, XdShape=4048, giniI=0.903106818905823, giniD=0.9849805056710775, ginigW=0.9708274327239166
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=53, XiShape=913, XdShape=3981, giniI=0.9114206502401121, giniD=0.9847539439567283, ginigW=0.9710732538947604
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=54, XiShape=976, XdShape=3918, giniI=0.9183204279763504, giniD=0.9845182546438852, ginigW=0.9713165630158684
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=55, XiShape=1048, XdShape=3846, giniI=0.924438042654857, giniD=0.9842836355159875, ginigW=0.9714683144456023
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=56, XiShape=1164, XdShape=3730, giniI=0.9288166767043374, giniD=0.9842580626612711, ginigW=0.9710717583592952
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=57, XiShape=1253, XdShape=3641, giniI=0.9335245848909146, giniD=0.9840765712538265, ginigW=0.9711338579492232
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=58, XiShape=1314, XdShape=3580, giniI=0.9373982101197964, giniD=0.9838196373396586, ginigW=0.9713558540607663
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=59, XiShape=1409, XdShape=3485, giniI=0.9410093583729457, giniD=0.9836685611011735, ginigW=0.9713868249662996
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=60, XiShape=1491, XdShape=3403, giniI=0.9442948772446887, giniD=0.9834526569830133, ginigW=0.9715228961350686
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=61, XiShape=1634, XdShape=3260, giniI=0.9459594090689135, giniD=0.983893259061312, ginigW=0.9712279728153825
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=62, XiShape=1690, XdShape=3204, giniI=0.9483834599628864, giniD=0.9836307923460218, ginigW=0.9714591552950413
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=63, XiShape=1786, XdShape=3108, giniI=0.9508940383648359, giniD=0.9835580202375569, ginigW=0.9716377358843326
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=64, XiShape=1890, XdShape=3004, giniI=0.9531216931216931, giniD=0.9835984333361112, ginigW=0.971828707344029
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=65, XiShape=2002, XdShape=2892, giniI=0.9550903641812732, giniD=0.9838032709109309, ginigW=0.9720576151543362
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=66, XiShape=2147, XdShape=2747, giniI=0.9563904443956093, giniD=0.9848344999323483, ginigW=0.9723560799819236
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=67, XiShape=2210, XdShape=2684, giniI=0.9580287053909625, giniD=0.9846651571047504, ginigW=0.9726368452356308
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=68, XiShape=2300, XdShape=2594, giniI=0.9597179584120983, giniD=0.9847863731557731, ginigW=0.9730051402357788
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=69, XiShape=2388, XdShape=2506, giniI=0.9612741260742574, giniD=0.9849322519807211, ginigW=0.9733884014158181
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=70, XiShape=2429, XdShape=2465, giniI=0.9622855163209882, giniD=0.9847034960028637, ginigW=0.9735769588865426
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=71, XiShape=2596, XdShape=2298, giniI=0.9628434524134558, giniD=0.9876806637777126, ginigW=0.9745058781827778
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=72, XiShape=2627, XdShape=2267, giniI=0.9635759598175893, giniD=0.9875284304891202, ginigW=0.9746712297424688
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=73, XiShape=2682, XdShape=2212, giniI=0.9646340032508823, giniD=0.987518761710741, ginigW=0.974977502579286
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=74, XiShape=2719, XdShape=2175, giniI=0.9654047951828774, giniD=0.9873798916633637, ginigW=0.9751710058173395
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=75, XiShape=2787, XdShape=2107, giniI=0.9664770657863686, giniD=0.9875937306634224, ginigW=0.9755683638852555
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=76, XiShape=2855, XdShape=2039, giniI=0.9674876472590871, giniD=0.9878646433776281, ginigW=0.9759773683636447
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=77, XiShape=2901, XdShape=1993, giniI=0.968259111640116, giniD=0.9878307140722584, ginigW=0.9762293208038388
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=78, XiShape=2932, XdShape=1962, giniI=0.9688149673639326, giniD=0.9876927680984579, ginigW=0.9763830599346597
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=79, XiShape=2992, XdShape=1902, giniI=0.9696510212616889, giniD=0.9878991730438158, ginigW=0.9767429674589929
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#  Col=Size, Val=80, XiShape=3014, XdShape=1880, giniI=0.9700391757289253, giniD=0.9877512449071979, ginigW=0.9768431581676569
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=81, XiShape=3076, XdShape=1818, giniI=0.970828520988026, giniD=0.9880645930379617, ginigW=0.9772312956073115
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=82, XiShape=3103, XdShape=1791, giniI=0.9712582575530899, giniD=0.9879292859857324, ginigW=0.9773591590493838
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=83, XiShape=3142, XdShape=1752, giniI=0.971813272145803, giniD=0.9878814297033006, ginigW=0.9775655018231091
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=84, XiShape=3190, XdShape=1704, giniI=0.9724287300635803, giniD=0.9879825706980537, ginigW=0.9778442887969565
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=85, XiShape=3212, XdShape=1682, giniI=0.9727582121217291, giniD=0.9878372245260371, ginigW=0.9779406597849997
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=86, XiShape=3252, XdShape=1642, giniI=0.9732729522867184, giniD=0.9878308589536838, ginigW=0.9781573173760435
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=87, XiShape=3276, XdShape=1618, giniI=0.9736094525471815, giniD=0.9876871903080456, ginigW=0.9782636780676306
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=88, XiShape=3299, XdShape=1595, giniI=0.9739275434213992, giniD=0.9875374652371735, ginigW=0.9783631431958495
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=89, XiShape=3332, XdShape=1562, giniI=0.9743433387760867, giniD=0.9874516567452674, ginigW=0.9785270724638391
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=90, XiShape=3349, XdShape=1545, giniI=0.9745773841743448, giniD=0.9872950639394226, ginigW=0.9785922626453389
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=91, XiShape=3400, XdShape=1494, giniI=0.9751093425605536, giniD=0.9875781573415483, ginigW=0.9789157196105751
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=92, XiShape=3422, XdShape=1472, giniI=0.9753870254047708, giniD=0.9874274500827033, ginigW=0.9790085017280067
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=93, XiShape=3456, XdShape=1438, giniI=0.9757721407750343, giniD=0.9873849284568855, ginigW=0.9791843166406865
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=94, XiShape=3482, XdShape=1412, giniI=0.97607685178984, giniD=0.9872551340593376, ginigW=0.9793019712349831
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=95, XiShape=3505, XdShape=1389, giniI=0.9763467310811333, giniD=0.9871037530820428, ginigW=0.9793997559195606
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=96, XiShape=3549, XdShape=1345, giniI=0.9767758882785867, giniD=0.9873163720788822, ginigW=0.9796726906307318
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=97, XiShape=3585, XdShape=1309, giniI=0.9771391334963401, giniD=0.9873654858151331, ginigW=0.9798743797540638
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=98, XiShape=3610, XdShape=1284, giniI=0.9774067111210012, giniD=0.9872477945672111, ginigW=0.9799886382041507
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=99, XiShape=3646, XdShape=1248, giniI=0.9777531806209978, giniD=0.9873335798816568, ginigW=0.9801962411598826
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=100, XiShape=3654, XdShape=1240, giniI=0.9778456941414871, giniD=0.9872112382934443, ginigW=0.9802186558800295
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=101, XiShape=3709, XdShape=1185, giniI=0.9782779727174018, giniD=0.9881507593156367, ginigW=0.9806685023698146
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=102, XiShape=3720, XdShape=1174, giniI=0.9783975026014569, giniD=0.9880154627955504, ginigW=0.9807047125049848
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=103, XiShape=3729, XdShape=1165, giniI=0.9784958276404179, giniD=0.9878892593343035, ginigW=0.9807319020015492
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=104, XiShape=3754, XdShape=1140, giniI=0.9787369409408512, giniD=0.9878331794398276, ginigW=0.9808558031984795
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=105, XiShape=3773, XdShape=1121, giniI=0.9789251948417231, giniD=0.9877045234080378, ginigW=0.9809361526109996
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=106, XiShape=3799, XdShape=1095, giniI=0.979165836647693, giniD=0.9876774879589666, ginigW=0.9810702621045473
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=107, XiShape=3816, XdShape=1078, giniI=0.9793312061319656, giniD=0.9875344639458077, ginigW=0.981138135417483
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=108, XiShape=3835, XdShape=1059, giniI=0.9795109546498405, giniD=0.9874050474328142, ginigW=0.9812191369663852
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=109, XiShape=3852, XdShape=1042, giniI=0.9796719267087858, giniD=0.9872568992893483, ginigW=0.9812868718311695
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=110, XiShape=3863, XdShape=1031, giniI=0.9797794229743823, giniD=0.9870973629324123, ginigW=0.9813210650047723
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=111, XiShape=3900, XdShape=994, giniI=0.9800712689020381, giniD=0.9875045038844739, ginigW=0.9815810023659819
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=112, XiShape=3907, XdShape=987, giniI=0.980139405760329, giniD=0.9873769335710745, ginigW=0.9815990379526474
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=113, XiShape=3921, XdShape=973, giniI=0.9802682291763216, giniD=0.987218095146552, ginigW=0.981649965912945
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=114, XiShape=3934, XdShape=960, giniI=0.980387502070901, giniD=0.9870529513888888, ginigW=0.9816949870208944
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=115, XiShape=3940, XdShape=954, giniI=0.9804448710350692, giniD=0.9869291387031983, ginigW=0.9817088659993918
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=116, XiShape=3959, XdShape=935, giniI=0.9806090860213373, giniD=0.9868054562612599, ginigW=0.9817929042016249
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=117, XiShape=3968, XdShape=926, giniI=0.9806918045980749, giniD=0.9866421917348124, ginigW=0.98181768495946
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=118, XiShape=3980, XdShape=914, giniI=0.9807989697229867, giniD=0.9864615104692863, ginigW=0.9818565018525571
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=119, XiShape=3999, XdShape=895, giniI=0.9809584178990484, giniD=0.9863312630691926, ginigW=0.9819409876635108
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=120, XiShape=4009, XdShape=885, giniI=0.981047071626879, giniD=0.9861482971049188, ginigW=0.9819695449713958
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=121, XiShape=4039, XdShape=855, giniI=0.9812724058773088, giniD=0.9863903423275537, ginigW=0.9821665284079502
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=122, XiShape=4047, XdShape=847, giniI=0.981342465467378, giniD=0.9862212489667679, ginigW=0.9821868319618576
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=123, XiShape=4063, XdShape=831, giniI=0.9814736143495302, giniD=0.9860562643995244, ginigW=0.9822517472043617
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=124, XiShape=4069, XdShape=825, giniI=0.981526036402893, giniD=0.9859056014692379, ginigW=0.9822643161699005
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=125, XiShape=4086, XdShape=808, giniI=0.9816621300866418, giniD=0.9857489461817469, ginigW=0.9823368639249836
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=126, XiShape=4117, XdShape=777, giniI=0.9818805524986328, giniD=0.9861808857947855, ginigW=0.9825632985082591
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=127, XiShape=4135, XdShape=759, giniI=0.9820190107452674, giniD=0.9860800824884001, ginigW=0.9826488336821366
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=128, XiShape=4145, XdShape=749, giniI=0.9820998456145661, giniD=0.9858841606342947, ginigW=0.9826790143823996
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=129, XiShape=4159, XdShape=735, giniI=0.9822088222998747, giniD=0.9857041047711602, ginigW=0.9827337574483003
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=130, XiShape=4164, XdShape=730, giniI=0.9822500809740136, giniD=0.9855545130418465, ginigW=0.9827429774614508
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=131, XiShape=4204, XdShape=690, giniI=0.9824957156475506, giniD=0.9871917664356228, ginigW=0.9831578069928243
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=132, XiShape=4210, XdShape=684, giniI=0.9825435424083593, giniD=0.9870430217844807, ginigW=0.9831724030322389
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=133, XiShape=4217, XdShape=677, giniI=0.982598692499374, giniD=0.9868806032347942, ginigW=0.9831910205680048
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=134, XiShape=4225, XdShape=669, giniI=0.9826609432442842, giniD=0.9867079571276317, ginigW=0.9832141619381868
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=135, XiShape=4239, XdShape=655, giniI=0.9827643767327294, giniD=0.986590525027679, ginigW=0.9832764582883469
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=136, XiShape=4255, XdShape=639, giniI=0.9828796149135391, giniD=0.9865375525628121, ginigW=0.9833572246719955
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=137, XiShape=4266, XdShape=628, giniI=0.9829611430583497, giniD=0.9863686153596495, ginigW=0.9833983912408623
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=138, XiShape=4270, XdShape=624, giniI=0.9829921734885838, giniD=0.9862343852728468, ginigW=0.9834055654283835
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=139, XiShape=4279, XdShape=615, giniI=0.9830592193564106, giniD=0.9860426994513848, ginigW=0.9834341356331594
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=140, XiShape=4281, XdShape=613, giniI=0.9830748262082295, giniD=0.9859621203452121, ginigW=0.9834364754329884
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=141, XiShape=4307, XdShape=587, giniI=0.9832421117366134, giniD=0.9866528910029632, ginigW=0.9836512101079552
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=142, XiShape=4308, XdShape=586, giniI=0.983249836843462, giniD=0.9866102109517874, ginigW=0.9836522028482594
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=143, XiShape=4317, XdShape=577, giniI=0.9833152585768704, giniD=0.9864325426742638, ginigW=0.9836827847158561
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=144, XiShape=4324, XdShape=570, giniI=0.983366615007689, giniD=0.9862480763311788, ginigW=0.9837022163469593
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=145, XiShape=4329, XdShape=565, giniI=0.9834036819483805, giniD=0.9860819171430809, ginigW=0.9837128774704496
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=146, XiShape=4343, XdShape=551, giniI=0.9835001170894443, giniD=0.9860112450222496, ginigW=0.9837828370508207
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=147, XiShape=4353, XdShape=541, giniI=0.9835705618285754, giniD=0.9858309900540179, ginigW=0.983820437527383
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=148, XiShape=4358, XdShape=536, giniI=0.9836069233606028, giniD=0.9856524281577189, ginigW=0.9838309508577942
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=149, XiShape=4365, XdShape=529, giniI=0.9836568874823028, giniD=0.9854453064418723, ginigW=0.9838502004429919
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=150, XiShape=4369, XdShape=525, giniI=0.983685961156761, giniD=0.9852807256235828, ginigW=0.983857038260374
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=151, XiShape=4383, XdShape=511, giniI=0.9837798113331594, giniD=0.9852137514791993, ginigW=0.9839295341395808
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=152, XiShape=4388, XdShape=506, giniI=0.9838154567565973, giniD=0.9850177318814541, ginigW=0.9839397622762495
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=153, XiShape=4398, XdShape=496, giniI=0.9838838026545201, giniD=0.984813995837669, ginigW=0.9839780764221626
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=154, XiShape=4400, XdShape=494, giniI=0.9838982438016529, giniD=0.9847071743513252, ginigW=0.9839798971918324
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=155, XiShape=4405, XdShape=489, giniI=0.9839334880263244, giniD=0.984497388351504, ginigW=0.9839898319697272
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=156, XiShape=4413, XdShape=481, giniI=0.9839884004621617, giniD=0.9842540445451048, ginigW=0.9840145089222957
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=157, XiShape=4426, XdShape=468, giniI=0.9840736934464199, giniD=0.98413872452334, ginigW=0.9840799121926396
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=158, XiShape=4428, XdShape=466, giniI=0.9840878730979421, giniD=0.9840207040100204, ginigW=0.9840814773490718
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=159, XiShape=4435, XdShape=459, giniI=0.984135572194634, giniD=0.9837621807377029, ginigW=0.9841005524400914
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=160, XiShape=4438, XdShape=456, giniI=0.9841565560734539, giniD=0.9835911049553709, ginigW=0.98410386998644
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=161, XiShape=4461, XdShape=433, giniI=0.9842929237882767, giniD=0.9846230978884094, ginigW=0.9843221361677941
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=162, XiShape=4463, XdShape=431, giniI=0.9843067974089645, giniD=0.9845015907537105, ginigW=0.9843239522785161
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=163, XiShape=4468, XdShape=426, giniI=0.9843406489918561, giniD=0.984273402543587, ginigW=0.9843347955004458
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=164, XiShape=4475, XdShape=419, giniI=0.98438715395899, giniD=0.9840226473989098, ginigW=0.9843559467156975
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=165, XiShape=4480, XdShape=414, giniI=0.9844207389987245, giniD=0.9837802515811337, ginigW=0.9843665580034481
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=167, XiShape=4488, XdShape=406, giniI=0.9844730531168877, giniD=0.9835230168167148, ginigW=0.9843942393167507
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=168, XiShape=4494, XdShape=400, giniI=0.984512703383971, giniD=0.98325, ginigW=0.9844094991842186
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=169, XiShape=4499, XdShape=395, giniI=0.98454587300302, giniD=0.9829834962345777, ginigW=0.9844197718948192
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=170, XiShape=4501, XdShape=393, giniI=0.9845594064583935, giniD=0.9828357580819559, ginigW=0.9844209933378499
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=171, XiShape=4514, XdShape=380, giniI=0.9846399200321787, giniD=0.9828116343490304, ginigW=0.9844979607842024
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=172, XiShape=4516, XdShape=378, giniI=0.9846533259168659, giniD=0.9826572604350382, ginigW=0.9844991549417677
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=173, XiShape=4523, XdShape=371, giniI=0.9846983963703534, giniD=0.9823526420180033, ginigW=0.9845205715103775
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=174, XiShape=4527, XdShape=367, giniI=0.9847246443046065, giniD=0.9820846542776323, ginigW=0.9845266720242837
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=175, XiShape=4528, XdShape=366, giniI=0.9847313418509408, giniD=0.9819940876108573, ginigW=0.984526635056525
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=176, XiShape=4529, XdShape=365, giniI=0.9847380349720924, giniD=0.9819027960217677, ginigW=0.9845265796764512
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=177, XiShape=4531, XdShape=363, giniI=0.9847513105358554, giniD=0.9817331845881808, ginigW=0.9845274487215918
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=178, XiShape=4535, XdShape=359, giniI=0.9847774202606457, giniD=0.9814480024208379, ginigW=0.9845331903864137
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=179, XiShape=4542, XdShape=352, giniI=0.9848219301006061, giniD=0.9810982696280991, ginigW=0.9845541065439404
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=180, XiShape=4543, XdShape=351, giniI=0.9848285628718927, giniD=0.9809985308560807, ginigW=0.9845538711600925
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=181, XiShape=4567, XdShape=327, giniI=0.9849599824791949, giniD=0.9834937201320502, ginigW=0.9848620119463963
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=182, XiShape=4577, XdShape=317, giniI=0.9850208571521724, giniD=0.9834310223009484, ginigW=0.9849178784746412
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=183, XiShape=4585, XdShape=309, giniI=0.9850700389706608, giniD=0.9832322661052985, ginigW=0.9849540046806329
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=184, XiShape=4587, XdShape=307, giniI=0.9850828653920909, giniD=0.9830555231355239, ginigW=0.9849556904691718
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=185, XiShape=4591, XdShape=303, giniI=0.9851080886571659, giniD=0.9827794660654184, ginigW=0.9849639177038967
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=186, XiShape=4598, XdShape=296, giniI=0.9851510793599199, giniD=0.9825146092037984, ginigW=0.9849916197836609
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=187, XiShape=4605, XdShape=289, giniI=0.9851938776833471, giniD=0.9822439865423067, ginigW=0.9850196810058317
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=188, XiShape=4611, XdShape=283, giniI=0.9852306919217296, giniD=0.9819325999825195, ginigW=0.9850399767564667
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=189, XiShape=4612, XdShape=282, giniI=0.9852370489443053, giniD=0.9818168100196167, ginigW=0.985039969382237
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=190, XiShape=4618, XdShape=276, giniI=0.9852736978711919, giniD=0.9814902331442974, ginigW=0.9850603271591725
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=191, XiShape=4625, XdShape=269, giniI=0.9853159503287071, giniD=0.9811915258219207, ginigW=0.9850892502485425
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=192, XiShape=4627, XdShape=267, giniI=0.9853284549782478, giniD=0.9809648052294183, ginigW=0.9850903890847176
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=193, XiShape=4630, XdShape=264, giniI=0.9853470417830936, giniD=0.9806588613406795, ginigW=0.9850941444318886
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=194, XiShape=4635, XdShape=259, giniI=0.9853774747506485, giniD=0.9802775748721695, ginigW=0.985107578128555
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=196, XiShape=4636, XdShape=258, giniI=0.9853837357931811, giniD=0.9801394146986359, ginigW=0.9851072677011515
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=197, XiShape=4639, XdShape=255, giniI=0.9854022158870214, giniD=0.9798077662437524, ginigW=0.985110719226001
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=198, XiShape=4641, XdShape=253, giniI=0.9854146090504887, giniD=0.9795497508162915, ginigW=0.9851114196076503
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=200, XiShape=4644, XdShape=250, giniI=0.9854330298288995, giniD=0.9792000000000001, ginigW=0.9851146282234183
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=201, XiShape=4658, XdShape=236, giniI=0.9855114291566323, giniD=0.9801781097385809, ginigW=0.985254244158132
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=202, XiShape=4661, XdShape=233, giniI=0.9855296596935842, giniD=0.9798301681740316, ginigW=0.9852583107920608
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=203, XiShape=4662, XdShape=232, giniI=0.9855358207996561, giniD=0.9796744946492271, ginigW=0.9852579647173308
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#  Col=Size, Val=205, XiShape=4663, XdShape=231, giniI=0.9855419779521936, giniD=0.9795168756207717, ginigW=0.9852575891825658
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=206, XiShape=4666, XdShape=228, giniI=0.9855601501335045, giniD=0.9791474299784549, ginigW=0.9852613965177809
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=208, XiShape=4670, XdShape=224, giniI=0.9855841422538505, giniD=0.9787149234693878, ginigW=0.9852697358362535
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=209, XiShape=4673, XdShape=221, giniI=0.9856022337206848, giniD=0.9783173972686882, ginigW=0.9852732699168656
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=210, XiShape=4675, XdShape=219, giniI=0.985614367010781, giniD=0.9780029607389338, ginigW=0.9852737666892578
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=211, XiShape=4684, XdShape=210, giniI=0.9856659040970916, giniD=0.9779138321995465, ginigW=0.9853332651313205
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=213, XiShape=4686, XdShape=208, giniI=0.9856779550022233, giniD=0.9775795118343195, ginigW=0.9853337628937388
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=214, XiShape=4690, XdShape=204, giniI=0.9857016471101695, giniD=0.9770761245674741, ginigW=0.9853421034651533
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=216, XiShape=4691, XdShape=203, giniI=0.9857076970960098, giniD=0.9768739838384819, ginigW=0.9853412803017151
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=217, XiShape=4692, XdShape=202, giniI=0.9857137432236692, giniD=0.9766689540241152, ginigW=0.9853404192722368
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=218, XiShape=4694, XdShape=200, giniI=0.9857257331472663, giniD=0.9763, ginigW=0.9853405376774148
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=220, XiShape=4695, XdShape=199, giniI=0.9857317677587355, giniD=0.9760864624630691, ginigW=0.9853395700158182
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=221, XiShape=4707, XdShape=187, giniI=0.985797926317335, giniD=0.9770368040264235, ginigW=0.9854631633691534
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=222, XiShape=4712, XdShape=182, giniI=0.9858269245736061, giniD=0.9765124984905205, ginigW=0.9854805360269936
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=223, XiShape=4713, XdShape=181, giniI=0.9858328933757583, giniD=0.9762827752510607, ginigW=0.9854796912138111
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=224, XiShape=4715, XdShape=179, giniI=0.9858447296538989, giniD=0.9758746605911176, ginigW=0.9854800704053828
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=225, XiShape=4716, XdShape=178, giniI=0.9858506871380053, giniD=0.975634389597273, ginigW=0.9854791094996216
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=226, XiShape=4720, XdShape=174, giniI=0.9858739406779661, giniD=0.9750297265160524, ginigW=0.9854883883150374
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=227, XiShape=4724, XdShape=170, giniI=0.9858971357816859, giniD=0.9743944636678201, ginigW=0.9854975742248087
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=228, XiShape=4727, XdShape=167, giniI=0.9859146281400696, giniD=0.9737889490480117, ginigW=0.9855008585429357
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=230, XiShape=4728, XdShape=166, giniI=0.9859205410543374, giniD=0.9735084917985194, ginigW=0.9854995357056521
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=232, XiShape=4731, XdShape=163, giniI=0.9859379892943376, giniD=0.9728631111445669, ginigW=0.9855025162378577
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=233, XiShape=4733, XdShape=161, giniI=0.9859496924485015, giniD=0.9723390301300103, ginigW=0.9855019366999773
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=234, XiShape=4737, XdShape=157, giniI=0.9859726980085581, giniD=0.9715607124021258, ginigW=0.9855103600967865
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=235, XiShape=4741, XdShape=153, giniI=0.9859956459648831, giniD=0.9707377504378658, ginigW=0.985518641875052
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=236, XiShape=4745, XdShape=149, giniI=0.986018536510619, giniD=0.9698662222422413, ginigW=0.9855267721407808
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=237, XiShape=4747, XdShape=147, giniI=0.9860301378241217, giniD=0.9692257855523162, ginigW=0.9855253891964234
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=238, XiShape=4750, XdShape=144, giniI=0.986047379501385, giniD=0.9683641975308642, ginigW=0.9855270733706627
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=239, XiShape=4752, XdShape=142, giniI=0.9860589445238014, giniD=0.9676651458044039, ginigW=0.9855252462364793
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=240, XiShape=4754, XdShape=140, giniI=0.9860704950276357, giniD=0.966938775510204, ginigW=0.9855232043181056
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=241, XiShape=4759, XdShape=135, giniI=0.9860986456203508, giniD=0.9658161865569272, ginigW=0.9855391580899948
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=243, XiShape=4760, XdShape=134, giniI=0.9861044417767106, giniD=0.9653597683225662, ginigW=0.9855364429530785
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=245, XiShape=4761, XdShape=133, giniI=0.9861102342904509, giniD=0.9648934365990163, ginigW=0.9855336437524531
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=246, XiShape=4762, XdShape=132, giniI=0.986116023164627, giniD=0.964416896235078, ginigW=0.9855307586050231
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=247, XiShape=4763, XdShape=131, giniI=0.9861218084022912, giniD=0.9639298409183613, ginigW=0.9855277855701713
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=248, XiShape=4764, XdShape=130, giniI=0.9861275900064929, giniD=0.963431952662722, ginigW=0.9855247226475451
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=250, XiShape=4766, XdShape=128, giniI=0.9861390542781969, giniD=0.9625244140625, ginigW=0.9855214257641779
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=253, XiShape=4771, XdShape=123, giniI=0.986166993249977, giniD=0.9610681472668385, ginigW=0.9855361885797838
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=255, XiShape=4772, XdShape=122, giniI=0.9861727463008932, giniD=0.9604944907282988, ginigW=0.9855326263213559
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=256, XiShape=4775, XdShape=119, giniI=0.9861897206765166, giniD=0.9591130569875008, ginigW=0.9855313383759459
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=257, XiShape=4776, XdShape=118, giniI=0.9861954594300368, giniD=0.9584889399597817, ginigW=0.9855274232025154
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=258, XiShape=4777, XdShape=117, giniI=0.9862011945891207, giniD=0.9578493681057783, ginigW=0.9855233924439325
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=260, XiShape=4778, XdShape=116, giniI=0.9862069261567731, giniD=0.957193816884661, ginigW=0.9855192431417414
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=264, XiShape=4779, XdShape=115, giniI=0.9862126541359958, giniD=0.9565217391304348, ginigW=0.9855149722345574
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=265, XiShape=4781, XdShape=113, giniI=0.9862240118442761, giniD=0.9552823243793562, ginigW=0.9855095838337458
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=266, XiShape=4783, XdShape=111, giniI=0.9862353553810976, giniD=0.9539810080350621, ginigW=0.9855037998936825
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=267, XiShape=4799, XdShape=95, giniI=0.9863158700536738, giniD=0.9655401662049862, ginigW=0.9859125819732436
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=269, XiShape=4800, XdShape=94, giniI=0.9863215277777778, giniD=0.9649162516976006, ginigW=0.9859103925200058
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=270, XiShape=4801, XdShape=93, giniI=0.9863271819759483, giniD=0.9642733263961152, ginigW=0.9859080956316646
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=273, XiShape=4803, XdShape=91, giniI=0.9863383931090678, giniD=0.9631686994324357, ginigW=0.9859075712609735
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=274, XiShape=4804, XdShape=90, giniI=0.9863440367831137, giniD=0.9624691358024692, ginigW=0.9859049805738253
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=275, XiShape=4807, XdShape=87, giniI=0.9863606870727017, giniD=0.9610252345091822, ginigW=0.9859103020353037
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=278, XiShape=4811, XdShape=83, giniI=0.9863826665844628, giniD=0.9595006532152708, ginigW=0.9859267599417079
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=279, XiShape=4813, XdShape=81, giniI=0.9863938086858652, giniD=0.958085657674135, ginigW=0.9859252839143184
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=280, XiShape=4814, XdShape=80, giniI=0.986399417707217, giniD=0.9571875000000001, ginigW=0.9859219037275322
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=285, XiShape=4819, XdShape=75, giniI=0.9864265493668044, giniD=0.9557333333333333, ginigW=0.9859561792804721
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=286, XiShape=4820, XdShape=74, giniI=0.9864321378764139, giniD=0.9547114682249818, ginigW=0.9859525037214882
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=288, XiShape=4830, XdShape=64, giniI=0.9864839748123572, giniD=0.9638671875, ginigW=0.9861882097146885
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#  Col=Size, Val=290, XiShape=4831, XdShape=63, giniI=0.986489526924989, giniD=0.962962962962963, ginigW=0.9861866716880443
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=292, XiShape=4832, XdShape=62, giniI=0.9864950755997544, giniD=0.9620187304890739, ginigW=0.9861849952162517
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=294, XiShape=4833, XdShape=61, giniI=0.9865006208394945, giniD=0.9610319806503629, ginigW=0.9861831735465773
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=295, XiShape=4835, XdShape=59, giniI=0.9865116154718963, giniD=0.9594943981614479, ginigW=0.9861859072942672
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=297, XiShape=4837, XdShape=57, giniI=0.9865225965396892, giniD=0.9578331794398277, ginigW=0.9861884533491105
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=298, XiShape=4838, XdShape=56, giniI=0.9865281247174899, giniD=0.9566326530612245, ginigW=0.9861860433090814
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=300, XiShape=4839, XdShape=55, giniI=0.9865336494772082, giniD=0.9553719008264463, ginigW=0.9861834459267808
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=302, XiShape=4845, XdShape=49, giniI=0.9865654484052053, giniD=0.9587671803415243, ginigW=0.9862871249203012
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=304, XiShape=4846, XdShape=48, giniI=0.9865709498445647, giniD=0.9574652777777778, ginigW=0.9862854835063535
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=306, XiShape=4847, XdShape=47, giniI=0.9865764478880013, giniD=0.9560887279311906, ginigW=0.9862836561352488
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=307, XiShape=4850, XdShape=44, giniI=0.9865926665958125, giniD=0.9545454545454546, ginigW=0.9863045429075786
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=310, XiShape=4851, XdShape=43, giniI=0.9865981511886628, giniD=0.952947539210384, ginigW=0.9863024878631486
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=311, XiShape=4855, XdShape=39, giniI=0.986619546667996, giniD=0.9533201840894149, ginigW=0.9863541859935857
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=315, XiShape=4856, XdShape=38, giniI=0.9866250145881791, giniD=0.9515235457063712, ginigW=0.9863524653814957
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=316, XiShape=4859, XdShape=35, giniI=0.9866411440193197, giniD=0.950204081632653, ginigW=0.9863805602057657
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=319, XiShape=4860, XdShape=34, giniI=0.9866465985876137, giniD=0.9480968858131488, ginigW=0.9863787828470474
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=320, XiShape=4861, XdShape=33, giniI=0.9866520497986379, giniD=0.945821854912764, ginigW=0.9863767338135063
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=321, XiShape=4862, XdShape=32, giniI=0.9866574976551505, giniD=0.943359375, ginigW=0.9863743877399554
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=330, XiShape=4863, XdShape=31, giniI=0.9866629421599069, giniD=0.9406867845993757, ginigW=0.9863717159881913
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=335, XiShape=4864, XdShape=30, giniI=0.9866683833156596, giniD=0.9377777777777778, ginigW=0.986368686101492
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=339, XiShape=4865, XdShape=29, giniI=0.9866738211251583, giniD=0.9346016646848989, ginigW=0.986365261146252
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=343, XiShape=4866, XdShape=28, giniI=0.9866792555911498, giniD=0.9311224489795918, ginigW=0.9863613989125385
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=348, XiShape=4869, XdShape=25, giniI=0.9866952858674221, giniD=0.9279999999999999, ginigW=0.9863954529808905
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=350, XiShape=4872, XdShape=22, giniI=0.9867112867739247, giniD=0.9256198347107438, ginigW=0.9864366623469958
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=359, XiShape=4874, XdShape=20, giniI=0.9867220219536421, giniD=0.9199999999999999, ginigW=0.9864493532901618
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=360, XiShape=4875, XdShape=19, giniI=0.9867274266929651, giniD=0.9141274238227146, ginigW=0.986445571348761
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=364, XiShape=4876, XdShape=18, giniI=0.9867328281159465, giniD=0.9074074074074074, ginigW=0.9864410713581301
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=377, XiShape=4877, XdShape=17, giniI=0.9867382262253024, giniD=0.8996539792387543, ginigW=0.9864357267976825
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=386, XiShape=4880, XdShape=14, giniI=0.986754148750336, giniD=0.8979591836734694, ginigW=0.9865001378163196
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=387, XiShape=4881, XdShape=13, giniI=0.9867595337355217, giniD=0.8875739644970414, ginigW=0.9864960657338666
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=390, XiShape=4882, XdShape=12, giniI=0.9867649154205577, giniD=0.875, ginigW=0.9864908698576139
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=393, XiShape=4883, XdShape=11, giniI=0.9867702938081435, giniD=0.859504132231405, ginigW=0.9864842439966716
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=395, XiShape=4885, XdShape=9, giniI=0.9867809568907807, giniD=0.8395061728395061, ginigW=0.9865101205490436
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=400, XiShape=4886, XdShape=8, giniI=0.986786325436489, giniD=0.8125, ginigW=0.9865014274790939
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=415, XiShape=4888, XdShape=6, giniI=0.9867969689623676, giniD=0.7777777777777777, ginigW=0.9865407133131834
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=420, XiShape=4889, XdShape=5, giniI=0.9868023276902691, giniD=0.72, ginigW=0.9865297466444065
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=505, XiShape=4891, XdShape=3, giniI=0.9868129517072675, giniD=0.6666666666666667, ginigW=0.9866167034736912
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=540, XiShape=4892, XdShape=2, giniI=0.9868183006413594, giniD=0.5, ginigW=0.9866193556880937
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#
#  Col=Size, Val=620, XiShape=4893, XdShape=1, giniI=0.9868236463047829, giniD=0.0, ginigW=0.9866220068184108
# Valores en giniWVal:
#     Thresh     GiniW
# 0      51  0.970575
#      col thresh     giniW
# 0  Rooms      3  0.262863
# 1   Size     51  0.970575
# Index :  0
#
#  Col=Toilets, Val=1, XiShape=0, XdShape=4894, giniI=0.0, giniD=0.5732317112987404, ginigW=0.5732317112987404
# Valores en giniWVal:
#     Thresh     GiniW
# 0       1  0.573232
#
#  Col=Toilets, Val=2, XiShape=905, XdShape=3989, giniI=0.0, giniD=0.4090917860667349, ginigW=0.33344240592975183
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.333442
#
#  Col=Toilets, Val=3, XiShape=3916, XdShape=978, giniI=0.3553889858635013, giniD=0.6482094839014557, ginigW=0.4139052194313638
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.333442
#
#  Col=Toilets, Val=4, XiShape=4368, XdShape=526, giniI=0.47118686601859683, giniD=0.5222643091558357, ginigW=0.4766765952973438
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.333442
#
#  Col=Toilets, Val=5, XiShape=4687, XdShape=207, giniI=0.536087701143424, giniD=0.290135125673878, ginigW=0.525684721347307
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.333442
#
#  Col=Toilets, Val=6, XiShape=4859, XdShape=35, giniI=0.5670967168364804, giniD=0.31999999999999984, ginigW=0.5653295764422678
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.333442
#
#  Col=Toilets, Val=7, XiShape=4887, XdShape=7, giniI=0.5720103058401644, giniD=0.0, ginigW=0.5711921464325467
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.333442
#        col thresh     giniW
# 0    Rooms      3  0.262863
# 1     Size     51  0.970575
# 2  Toilets      2  0.333442
# Index :  0
#
#  Col=Parking, Val=0, XiShape=0, XdShape=4894, giniI=0.0, giniD=0.5480646593770775, ginigW=0.5480646593770775
# Valores en giniWVal:
#     Thresh     GiniW
# 0       0  0.548065
#
#  Col=Parking, Val=1, XiShape=150, XdShape=4744, giniI=0.0, giniD=0.5200332042747172, ginigW=0.5040943034489699
# Valores en giniWVal:
#     Thresh     GiniW
# 0       1  0.504094
#
#  Col=Parking, Val=2, XiShape=3127, XdShape=1767, giniI=0.09133649187896786, giniD=0.37885922795743765, ginigW=0.19514782711612683
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.195148
#
#  Col=Parking, Val=3, XiShape=4492, XdShape=402, giniI=0.4673297695953388, giniD=0.5287492883839509, ginigW=0.4723748547103821
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.195148
#
#  Col=Parking, Val=4, XiShape=4731, XdShape=163, giniI=0.5172370332155753, giniD=0.2835635515073959, ginigW=0.5094542834161406
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.195148
#
#  Col=Parking, Val=5, XiShape=4867, XdShape=27, giniI=0.5430592237174341, giniD=0.2606310013717421, ginigW=0.5415010786411502
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.195148
#
#  Col=Parking, Val=6, XiShape=4890, XdShape=4, giniI=0.5473254126571903, giniD=0.375, ginigW=0.5471845663861178
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.195148
#
#  Col=Parking, Val=7, XiShape=4893, XdShape=1, giniI=0.5478799549684733, giniD=0.0, ginigW=0.5477680056519697
# Valores en giniWVal:
#     Thresh     GiniW
# 0       2  0.195148
#        col thresh     giniW
# 0    Rooms      3  0.262863
# 1     Size     51  0.970575
# 2  Toilets      2  0.333442
# 3  Parking      2  0.195148
# Index :  3
